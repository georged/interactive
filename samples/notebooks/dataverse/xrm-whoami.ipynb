// %% [markdown]
// # Hello world
//
// First we need to make sure our voice is heard. Use `display` function to output *things* to the notebook output

// %%
display("Hello, world");

// %% [markdown]
// # New client
//
// No matter how hard you try, you can forget about XrmTooling from .NET Framework.
//
// **tl&amp;dr**: it relies on ADAL which is not available here.
//
// Let's start with bringing the nuget package we need and adding namespaces.

// %%
#r "nuget: Microsoft.PowerPlatform.Dataverse.Client"

using Microsoft.PowerPlatform.Dataverse.Client;
using Microsoft.Crm.Sdk.Messages;

// %% [markdown]
// # Connect
//
// Let's connect the client! Simply use `ServiceClient` instead of `CrmServiceClient` and you are good to go.

// %%
var conn = new ServiceClient(new Uri("https://enabler.crm6.dynamics.com"),  "e938ec06-1233-4fa4-9609-62e40712be13",  "7-h3X.0_ecN2DPgGu9VD.jbCr.k54qXM22",  true);

if(conn.IsReady) {
  display($"You are connected to the organization {conn.OrganizationDetail.FriendlyName}");
}
else {
  display("No connection");
}
// Out:
// You are connected to the organization Enableur

// %%
if(conn.IsReady) {
  var whoamiResponse = conn.Execute(new WhoAmIRequest());
  display(whoamiResponse);
}
// Out:
// <table><thead><tr><th>UserId</th><th>BusinessUnitId</th><th>OrganizationId</th><th>ResponseName</th><th>Results</th><th>ExtensionData</th></tr></thead><tbody><tr><td><div class="dni-plaintext">c4e9bb40-79bc-eb11-bacc-000d3a6b031f</div></td><td><div class="dni-plaintext">4f296393-127c-ea11-a813-000d3a6a9918</div></td><td><div class="dni-plaintext">41f17a55-5c87-4828-8917-aa27fbafa6d9</div></td><td><div class="dni-plaintext">WhoAmI</div></td><td><div class="dni-plaintext">[ UserId: c4e9bb40-79bc-eb11-bacc-000d3a6b031f, BusinessUnitId: 4f296393-127c-ea11-a813-000d3a6a9918, OrganizationId: 41f17a55-5c87-4828-8917-aa27fbafa6d9 ]</div></td><td><div class="dni-plaintext">System.Runtime.Serialization.ExtensionDataObject</div></td></tr></tbody></table>

// %%
try {
  var conn = new ServiceClient(new Uri("https://enabler.crm6.dynamics.com"),  "e938ec06-1233-4fa4-9609-62e40712be13",  "foobar",  true);
}
catch(Exception ex) {
  display(ex.Message);
}
// Out:
// Failed to connect to Dataverse
// <table><thead><tr><th>InnerExceptions</th><th>Message</th><th>TargetSite</th><th>StackTrace</th><th>Data</th><th>InnerException</th><th>HelpLink</th><th>Source</th><th>HResult</th></tr></thead><tbody><tr><td><div class="dni-plaintext">[ { MSAL.NetCore.4.25.0.0.MsalServiceException:
// 	ErrorCode: invalid_client
// Microsoft.Identity.Client.MsalServiceException: A configuration issue is preventing authentication - check the error message from the server for details. You can modify the configuration in the application registration portal. See https://aka.ms/msal-net-invalid-client for details.  Original exception: AADSTS7000215: Invalid client secret is provided.
// Trace ID: a5458920-1813-4c02-a7cb-4c1f9c814900
// Correlation ID: b0d5d935-5ce3-47c6-baa6-51ae23cd3a63
// Timestamp: 2021-07-28 03:07:30Z
//    at Microsoft.PowerPlatform.Dataverse.Client.ConnectionService.InitServiceAsync()
// 	StatusCode: 401
// 	ResponseBody: {&quot;error&quot;:&quot;invalid_client&quot;,&quot;error_description&quot;:&quot;AADSTS7000215: Invalid client secret is provided.\r\nTrace ID: a5458920-1813-4c02-a7cb-4c1f9c814900\r\nCorrelation ID: b0d5d935-5ce3-47c6-baa6-51ae23cd3a63\r\nTimestamp: 2021-07-28 03:07:30Z&quot;,&quot;error_codes&quot;:[7000215],&quot;timestamp&quot;:&quot;2021-07-28 03:07:30Z&quot;,&quot;trace_id&quot;:&quot;a5458920-1813-4c02-a7cb-4c1f9c814900&quot;,&quot;correlation_id&quot;:&quot;b0d5d935-5ce3-47c6-baa6-51ae23cd3a63&quot;,&quot;error_uri&quot;:&quot;https://login.microsoftonline.com/error?code=7000215&quot;}
// 	Headers: Cache-Control: no-store, no-cache
// Pragma: no-cache
// Strict-Transport-Security: max-age=31536000; includeSubDomains
// X-Content-Type-Options: nosniff
// P3P: CP=&quot;DSP CUR OTPi IND OTRi ONL FIN&quot;
// client-request-id: b0d5d935-5ce3-47c6-baa6-51ae23cd3a63
// x-ms-request-id: a5458920-1813-4c02-a7cb-4c1f9c814900
// x-ms-ests-server: 2.1.11898.12 - AUELR2 ProdSlices
// x-ms-clitelem: 1,7000215,0,,
// Set-Cookie: fpc=AtBgTkwwCKtBiogdESTOQejbUOzXAwAAAPi_ktgOAAAA3LKi8AMAAAC3v5LYDgAAAA; expires=Fri, 27-Aug-2021 03:07:30 GMT; path=/; secure; HttpOnly; SameSite=None, x-ms-gateway-slice=estsfd; path=/; secure; httponly, stsservicecookie=estsfd; path=/; secure; samesite=none; httponly
// Date: Wed, 28 Jul 2021 03:07:29 GMT
// : StatusCode: 401, Claims: &lt;null&gt;, ResponseBody: {&quot;error&quot;:&quot;invalid_client&quot;,&quot;error_description&quot;:&quot;AADSTS7000215: Invalid client secret is provided.\r\nTrace ID: a5458920-1813-4c02-a7cb-4c1f9c814900\r\nCorrelation ID: b0d5d935-5ce3-47c6-baa6-51ae23cd3a63\r\nTimestamp: 2021-07-28 03:07:30Z&quot;,&quot;error_codes&quot;:[7000215],&quot;timestamp&quot;:&quot;2021-07-28 03:07:30Z&quot;,&quot;trace_id&quot;:&quot;a5458920-1813-4c02-a7cb-4c1f9c814900&quot;,&quot;correlation_id&quot;:&quot;b0d5d935-5ce3-47c6-baa6-51ae23cd3a63&quot;,&quot;error_uri&quot;:&quot;https://login.microsoftonline.com/error?code=7000215&quot;}, Headers: [ { [Cache-Control, System.String[]]: Key: Cache-Control, Value: [ no-store, no-cache ] }, { [Pragma, System.String[]]: Key: Pragma, Value: [ no-cache ] }, { [Strict-Transport-Security, System.String[]]: Key: Strict-Transport-Security, Value: [ max-age=31536000; includeSubDomains ] }, { [X-Content-Type-Options, System.String[]]: Key: X-Content-Type-Options, Value: [ nosniff ] }, { [P3P, System.String[]]: Key: P3P, Value: [ CP=&quot;DSP CUR OTPi IND OTRi ONL FIN&quot; ] }, { [client-request-id, System.String[]]: Key: client-request-id, Value: [ b0d5d935-5ce3-47c6-baa6-51ae23cd3a63 ] }, { [x-ms-request-id, System.String[]]: Key: x-ms-request-id, Value: [ a5458920-1813-4c02-a7cb-4c1f9c814900 ] }, { [x-ms-ests-server, System.String[]]: Key: x-ms-ests-server, Value: [ 2.1.11898.12 - AUELR2 ProdSlices ] }, { [x-ms-clitelem, System.String[]]: Key: x-ms-clitelem, Value: [ 1,7000215,0,, ] }, { [Set-Cookie, System.String[]]: Key: Set-Cookie, Value: [ fpc=AtBgTkwwCKtBiogdESTOQejbUOzXAwAAAPi_ktgOAAAA3LKi8AMAAAC3v5LYDgAAAA; expires=Fri, 27-Aug-2021 03:07:30 GMT; path=/; secure; HttpOnly; SameSite=None, x-ms-gateway-slice=estsfd; path=/; secure; httponly, stsservicecookie=estsfd; path=/; secure; samesite=none; httponly ] }, { [Date, System.String[]]: Key: Date, Value: [ Wed, 28 Jul 2021 03:07:29 GMT ] } ], CorrelationId: b0d5d935-5ce3-47c6-baa6-51ae23cd3a63, ErrorCode: invalid_client, TargetSite: { Void ThrowServerException(Microsoft.Identity.Client.Http.HttpResponse, Microsoft.Identity.Client.Internal.RequestContext): Name: ThrowServerException, DeclaringType: Microsoft.Identity.Client.OAuth2.OAuth2Client, ReflectedType: Microsoft.Identity.Client.OAuth2.OAuth2Client, MemberType: Method, MetadataToken: 100668475, Module: { Microsoft.Identity.Client.dll: MDStreamVersion: 131072, FullyQualifiedName: C:\Users\me\.nuget\packages\microsoft.identity.client\4.25.0\lib\netcoreapp2.1\Microsoft.Identity.Client.dll, ModuleVersionId: dbc656ae-4b03-425d-8f76-3010d4dfdfa0, MetadataToken: 1, ScopeName: Microsoft.Identity.Client.dll, Name: Microsoft.Identity.Client.dll, Assembly: { Microsoft.Identity.Client, Version=4.25.0.0, Culture=neutral, PublicKeyToken=0a613f4dd989e8ae: CodeBase: file:///C:/Users/me/.nuget/packages/microsoft.identity.client/4.25.0/lib/netcoreapp2.1/Microsoft.Identity.Client.dll, FullName: Microsoft.Identity.Client, Version=4.25.0.0, Culture=neutral, PublicKeyToken=0a613f4dd989e8ae, EntryPoint: &lt;null&gt;, DefinedTypes: [ Microsoft.Identity.Json.ConstructorHandling, Microsoft.Identity.Json.DateFormatHandling, Microsoft.Identity.Json.DateParseHandling, Microsoft.Identity.Json.DateTimeZoneHandling, Microsoft.Identity.Json.DefaultJsonNameTable, Microsoft.Identity.Json.DefaultValueHandling, Microsoft.Identity.Json.FloatFormatHandling, Microsoft.Identity.Json.FloatParseHandling, Microsoft.Identity.Json.Formatting, Microsoft.Identity.Json.IArrayPool`1[T], Microsoft.Identity.Json.IJsonLineInfo, Microsoft.Identity.Json.JsonArrayAttribute, Microsoft.Identity.Json.JsonConstructorAttribute, Microsoft.Identity.Json.JsonContainerAttribute, Microsoft.Identity.Json.JsonConvert, Microsoft.Identity.Json.JsonConverter, Microsoft.Identity.Json.JsonConverter`1[T], Microsoft.Identity.Json.JsonConverterAttribute, Microsoft.Identity.Json.JsonConverterCollection, Microsoft.Identity.Json.JsonDictionaryAt ...
